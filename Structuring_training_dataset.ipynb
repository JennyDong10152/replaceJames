# %%
def indexing(sentence):
    idx = 0
    word_idx_lst = []
    for word in sentence.split():
        if word[-1] == ',' or word[-1] == '.':
            word_idx_lst.append((word[:-1], idx))
            idx += 1
            word_idx_lst.append((word[-1], idx))
        else:
            word_idx_lst.append((word, idx))
        idx += 1
    return word_idx_lst

# %%
train_sentences = [
    "profit for the year was 24.0 million dollars, 372.0 million dollars and 1,096.4 million dollars in 2021, 2022 and 2023, respectively.",
    "adjusted profit was 769.6 million dollars , 788.1 million dollars and 1,459.0 million dollars in 2021 , 2022 and 2023 , respectively.",
    "The revenue in 2021 was 4.38 billion dollars",
    "The revenue in 2022 was 5.56 billion dollars",
    "The revenue in 2023 was 7.68 billion dollars",
    "Profit in 2021 was 24 million dollars",
    "Profit in 2022 was 372 million dollars",
    "Profit in 2023 was 1.10 billion dollars",
    "Adjusted profit in 2021 was 769.6 million dollars",
    "Adjusted profit in 2022 was 788.1 million dollars",
    "Adjusted profit in 2023 was 1.46 billion dollars"
]

# %%
for sentence in train_sentences:
    print(indexing(sentence))
# Out:
# [('profit', 0), ('for', 1), ('the', 2), ('year', 3), ('was', 4), ('24.0', 5), ('million', 6), ('dollars', 7), (',', 8), ('372.0', 9), ('million', 10), ('dollars', 11), ('and', 12), ('1,096.4', 13), ('million', 14), ('dollars', 15), ('in', 16), ('2021', 17), (',', 18), ('2022', 19), ('and', 20), ('2023', 21), (',', 22), ('respectively', 23), ('.', 24)]
# [('adjusted', 0), ('profit', 1), ('was', 2), ('769.6', 3), ('million', 4), ('dollars', 5), ('', 6), (',', 7), ('788.1', 8), ('million', 9), ('dollars', 10), ('and', 11), ('1,459.0', 12), ('million', 13), ('dollars', 14), ('in', 15), ('2021', 16), ('', 17), (',', 18), ('2022', 19), ('and', 20), ('2023', 21), ('', 22), (',', 23), ('respectively', 24), ('.', 25)]
# [('The', 0), ('revenue', 1), ('in', 2), ('2021', 3), ('was', 4), ('4.38', 5), ('billion', 6), ('dollars', 7)]
# [('The', 0), ('revenue', 1), ('in', 2), ('2022', 3), ('was', 4), ('5.56', 5), ('billion', 6), ('dollars', 7)]
# [('The', 0), ('revenue', 1), ('in', 2), ('2023', 3), ('was', 4), ('7.68', 5), ('billion', 6), ('dollars', 7)]
# [('Profit', 0), ('in', 1), ('2021', 2), ('was', 3), ('24', 4), ('million', 5), ('dollars', 6)]
# [('Profit', 0), ('in', 1), ('2022', 2), ('was', 3), ('372', 4), ('million', 5), ('dollars', 6)]
# [('Profit', 0), ('in', 1), ('2023', 2), ('was', 3), ('1.10', 4), ('billion', 5), ('dollars', 6)]
# [('Adjusted', 0), ('profit', 1), ('in', 2), ('2021', 3), ('was', 4), ('769.6', 5), ('million', 6), ('dollars', 7)]
# [('Adjusted', 0), ('profit', 1), ('in', 2), ('2022', 3), ('was', 4), ('788.1', 5), ('million', 6), ('dollars', 7)]
# [('Adjusted', 0), ('profit', 1), ('in', 2), ('2023', 3), ('was', 4), ('1.46', 5), ('billion', 6), ('dollars', 7)]
